# %%
from flask import Flask, render_template, jsonify, redirect, send_from_directory, request, url_for
import  pymysql 
import json
import datetime
app = Flask(__name__)

def myconverter(o):
    if isinstance(o, datetime.datetime):
        return o.__str__()

def get_club_json():
    conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='root', db='afterclasscalendar', charset='utf8')
    cursor = conn.cursor()
    query = "select * from 社團"
    cursor.execute(query)
    result = cursor.fetchall()
    clubs = []

    for row in result:
        clubs.append({'id': row[0], 'name': row[1], 'type': row[2], 'office': row[3], 'session': row[4], 'teacher': row[5], 'fee': row[6], 'introduction': row[7], 'logo': row[8]})
    return json.dumps(clubs)
# print(json)

def get_activity_json():
    conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='root', db='afterclasscalendar', charset='utf8')
    cursor = conn.cursor()
    query = "select * from 活動 order by 活動時間 desc"
    cursor.execute(query)
    result = cursor.fetchall()
    activities = []
#     print(result)

    for row in result:
        activities.append({'id': row[0], 'name': row[1], 'time': row[2], 'location': row[3], 'fee': row[4], 'clubId': row[5], 'url': row[6]})
#     print(activities)
#     return json.dumps(activities)
    return json.dumps(activities, default = myconverter)


@app.route('/club',methods=['GET','POST'])
def hello():
    if request.method=='POST':
        get_numb=request.get_data()
        print(get_numb)
        return get_numb
    return get_club_json()

@app.route('/activity',methods=['GET','POST'])
def hello2():
    if request.method=='POST':
        return "123"
    return get_activity_json()
@app.route('/keynote',methods=['GET','POST'])
def hello3():
    return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
if __name__ == '__main__':
    app.run(debug=False, host='140.134.79.128', port='40128')
    
cursor.close()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://140.134.79.128:40128/ (Press CTRL+C to quit)
# [2020-06-16 19:01:03,830] ERROR in app: Exception on /keynote [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-29-d8c700c43d4d>", line 55, in hello3
#     return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2215, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 358, in url_for
#     endpoint, values, method=method, force_external=external
#   File "/usr/local/lib/python3.6/dist-packages/werkzeug/routing.py", line 2020, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg'. Did you mean 'hello' instead?
# 140.134.79.133 - - [16/Jun/2020 19:01:03] "GET /keynote HTTP/1.1" 500 -
# [2020-06-16 19:01:04,990] ERROR in app: Exception on /keynote [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-29-d8c700c43d4d>", line 55, in hello3
#     return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2215, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 358, in url_for
#     endpoint, values, method=method, force_external=external
#   File "/usr/local/lib/python3.6/dist-packages/werkzeug/routing.py", line 2020, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg'. Did you mean 'hello' instead?
# 140.134.79.133 - - [16/Jun/2020 19:01:04] "GET /keynote HTTP/1.1" 500 -
# [2020-06-16 19:01:05,199] ERROR in app: Exception on /keynote [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-29-d8c700c43d4d>", line 55, in hello3
#     return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2215, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 358, in url_for
#     endpoint, values, method=method, force_external=external
#   File "/usr/local/lib/python3.6/dist-packages/werkzeug/routing.py", line 2020, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg'. Did you mean 'hello' instead?
# 140.134.79.133 - - [16/Jun/2020 19:01:05] "GET /keynote HTTP/1.1" 500 -
# [2020-06-16 19:01:05,398] ERROR in app: Exception on /keynote [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-29-d8c700c43d4d>", line 55, in hello3
#     return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2215, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 358, in url_for
#     endpoint, values, method=method, force_external=external
#   File "/usr/local/lib/python3.6/dist-packages/werkzeug/routing.py", line 2020, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg'. Did you mean 'hello' instead?
# 140.134.79.133 - - [16/Jun/2020 19:01:05] "GET /keynote HTTP/1.1" 500 -
# [2020-06-16 19:01:05,547] ERROR in app: Exception on /keynote [GET]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-29-d8c700c43d4d>", line 55, in hello3
#     return url_for('https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg')
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2215, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/helpers.py", line 358, in url_for
#     endpoint, values, method=method, force_external=external
#   File "/usr/local/lib/python3.6/dist-packages/werkzeug/routing.py", line 2020, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'https://www.icloud.com/keynote/0KnGPphA7ecPzFTLC6_-orghg'. Did you mean 'hello' instead?
# 140.134.79.133 - - [16/Jun/2020 19:01:05] "GET /keynote HTTP/1.1" 500 -
